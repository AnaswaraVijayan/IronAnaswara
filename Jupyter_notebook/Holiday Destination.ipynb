# %% [markdown]
# # ** Holiday Destination of the user

# %%
user_name= input('Enter User Name: ')
print('User name is', user_name)
# Out:
# Enter User Name: Anaswara
# User name is Anaswara

# %% [markdown]
# ![WhatsApp%20Image%202023-04-28%20at%2013.37.52%20%281%29%20-%20Copy.jpeg](attachment:WhatsApp%20Image%202023-04-28%20at%2013.37.52%20%281%29%20-%20Copy.jpeg)

# %%
destination_1= input('Enter user destination ')
print('User destination is', destination_1)
# Out:
# Enter user destination Majorca
# User destination is Majorca

# %% [markdown]
# ![WhatsApp%20Image%202023-04-28%20at%2013.37.52%20%281%29%20-%20Copy.jpeg](attachment:WhatsApp%20Image%202023-04-28%20at%2013.37.52%20%281%29%20-%20Copy.jpeg)

# %% [markdown]
# - the place is an island
# - it has many beaches
# - the climate is tropical
